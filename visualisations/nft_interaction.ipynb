# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from CSV
data = pd.read_csv('simulated_data.csv')

# NFT Ownership Analysis
def nft_ownership_analysis():
    nft_count = data['totalNft'].value_counts()
    
    # Visualization: Pie chart for NFT ownership distribution
    plt.figure(figsize=(8, 8))
    plt.pie(nft_count.values, labels=nft_count.index, autopct='%1.1f%%')
    plt.title('NFT Ownership Distribution')
    plt.show()

# NFT Engagement Analysis
def nft_engagement_analysis():
    engagement = data[['totalProposalInteractionInSpace', 'totalProposalInteractionNonSpace']]
    
    # Analysis: Calculate average engagement for each NFT owner
    
    # Generate insightful visualizations based on the analysis

# NFT Rewards Analysis
def nft_rewards_analysis():
    rewards = data['rewardsNft']
    
    # Analysis: Calculate total rewards earned by each NFT owner
    
    # Generate insightful visualizations based on the analysis

# NFT Activity Over Time Analysis
def nft_activity_over_time_analysis():
    activity = data[['date_created', 'totalNft']]
    
    # Analysis: Analyze the number of NFT interactions over time
    
    # Generate insightful visualizations based on the analysis

# NFT Engagement Correlation Analysis
def nft_engagement_correlation_analysis():
    engagement = data[['totalProposalInteractionInSpace', 'totalProposalInteractionNonSpace']]
    follow_count = data['followCount']
    
    # Analysis: Calculate the correlation between NFT engagement and follow count
    
    # Generate insightful visualizations based on the analysis

# Perform the analysis
nft_ownership_analysis()
nft_engagement_analysis()
nft_rewards_analysis()
nft_activity_over_time_analysis()
nft_engagement_correlation_analysis()
